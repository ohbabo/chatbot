# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", model="SungBeom/whisper-small-ko")

audio_file = "processed_P0685-01-25-05.wav"

# 음성을 텍스트로 변환
try:
    result = pipe(audio_file)
    print("Transcription:", result["text"])
except Exception as e:
    print("오류 발생:", e)
# Out:
# Device set to use cuda:0
# 오류 발생: index -2 is out of bounds for dimension 0 with size 0
# /root/flaskddb/venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", model="openai/whisper-small", tokenizer="openai/whisper-small")
# Out:
# Device set to use cuda:0
# /root/flaskddb/venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# ...

# %%
result = pipe("P0685-01-25-05.wav",return_timestamps=True)
print("Transcription:", result["text"])
# Out:
# /root/flaskddb/venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcription:  무엇이고 차별할 줄 모르는 무지한 검은 액체의 범남 속에 녹여버리려는 이 목적이 없는 실험실 속에서 나의 작은 탐험선인 지구가 갑자기 그 항해를 잊어버린다면 나는 대체 어느 구석에서 나의 해돌을 편단 말이냐.

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe1 = pipeline("automatic-speech-recognition", model="openai/whisper-tiny")
# Out:
# Device set to use cuda:0

# %%
result = pipe1("P0685-01-25-05.wav",return_timestamps=True)
print("Transcription:", result["text"])
# Out:
# /root/flaskddb/venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcription:  무엇이고 차별을 줄 모르는 무지한 검은 액체이 범 남 속에 녹여버리려는 이 목적이 없는 실험실 속에서 나의 작은 탐험선인 치고가 갑자기 그 항해를 잊어버린다면 나는 대체 어느 구석에서 나이 헤돌을 편단 마리냐

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe2 = pipeline("automatic-speech-recognition", model="openai/whisper-base")
# Out:
# Device set to use cuda:0

# %%
result = pipe2("P0685-01-25-05.wav",return_timestamps=True)
print("Transcription:", result["text"])
# Out:
# /root/flaskddb/venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcription:  무엇이고 차별할 줄 모르는 무지한 검은 엑체에 범남 속에 녹여버리려는 이 목적이 없는 실험실 속에서 나의 작은 탐험선인 지구가 갑자기 그 항해를 잊어버린다면 나는 대체 어느 구석에서 나의 해도를 편단 말이냐

# %%
result = pipe3("P0685-01-25-05.wav",return_timestamps='word')
print("Transcription:", result["text"])
# Out:
# Transcription: 무엇이고 차별할 줄 모르는 우지한 건은 액체이 범남 속에 로여버리는 이 목적이 없는 실험칠 속에서 나 자은 탐음선인 지구가 갑자이 그 항해를 잊어버린다면 나는 대체 어느 구석에서 나이 해도를 판단 마이냐
